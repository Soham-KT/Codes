# %%
frame = {
    'age' : ['youth','youth','middle aged','senior','senior','senior','middle aged','youth','youth','senior','youth','middle aged','middle aged','senior'],
    'income' : ['high','high','high','medium','low','low','low','medium','low','medium','medium','medium','high','medium'],
    'student' : ['no','no','no','no','yes','yes','yes','no','yes','yes','yes','no','yes','no'],
    'credit_rating' : ['fair','excellent','fair','fair','fair','excellent','excellent','fair','fair','fair','excellent','excellent','fair','excellent'],
    'buys_computer' : ['no','no','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','no']
}

# %%
import pandas as pd

df = pd.DataFrame.from_dict(frame)
df
# Out:
#             age  income student credit_rating buys_computer
# 0         youth    high      no          fair            no
# 1         youth    high      no     excellent            no
# 2   middle aged    high      no          fair           yes
# 3        senior  medium      no          fair           yes
# 4        senior     low     yes          fair           yes
# 5        senior     low     yes     excellent            no
# 6   middle aged     low     yes     excellent           yes
# 7         youth  medium      no          fair            no
# 8         youth     low     yes          fair           yes
# 9        senior  medium     yes          fair           yes
# 10        youth  medium     yes     excellent           yes
# 11  middle aged  medium      no     excellent           yes
# 12  middle aged    high     yes          fair           yes
# 13       senior  medium      no     excellent            no

# %%
# df_new = pd.get_dummies(df, columns=['age','income','student','credit_rating'])
# df_new
# Out:
#    buys_computer  age_middle aged  age_senior  age_youth  income_high  \
# 0             no            False       False       True         True
# 1             no            False       False       True         True
# 2            yes             True       False      False         True
# 3            yes            False        True      False        False
# 4            yes            False        True      False        False
# 5             no            False        True      False        False
# 6            yes             True       False      False        False
# 7             no            False       False       True        False
# 8            yes            False       False       True        False
# 9            yes            False        True      False        False
# 10           yes            False       False       True        False
# 11           yes             True       False      False        False
# ...

# %%
X = df_new.drop(['buys_computer'], axis=1)
Y = df_new['buys_computer']

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

features = ['age_middle aged','age_senior','age_youth','income_high','income_low','income_medium','student_no','student_yes','credit_rating_excellent','credit_rating_fair']
Dtree = DecisionTreeClassifier(criterion='entropy')
Dtree.fit(X, Y)
plot_tree(Dtree, fontsize=5, filled=True, feature_names=features)
# Out:
# [Text(0.5555555555555556, 0.9, 'age_middle aged <= 0.5\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.4444444444444444, 0.7, 'student_no <= 0.5\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.2222222222222222, 0.5, 'credit_rating_excellent <= 0.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1111111111111111, 0.3, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3333333333333333, 0.3, 'income_medium <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2222222222222222, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4444444444444444, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.5, 'age_senior <= 0.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5555555555555556, 0.3, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7777777777777778, 0.3, 'credit_rating_fair <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
# ...
